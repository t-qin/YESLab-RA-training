# %% [markdown]
# # Clean correlational study pilot data
# *Author*: Shangcheng Zhao
#
# *Date*: 03/28/2024

# %%
# import pandas as pd
# import numpy as np
# import os
# import glob

# %% [markdown]
# First, we will load the data. Please check and make necessary changes according the folder structure on your computer.

# %%
import os

# define path
scriptpath = os.path.abspath('') # path to this script

# Go back twice to get the root path
# rootpath = os.path.dirname(os.path.dirname(scriptpath))
rootpath = scriptpath # In current setting, the working directory is the script's directory
rootpath
# Out:
# '/Users/xmr./Desktop/YESLab-RA-training/Data_cleaning'

# %%
# load data
import re
import glob
import pandas as pd

# questionnaires
filename = glob.glob(os.path.join(rootpath, 'data', 'SAD_Post_Questionnaire_June 3*.csv')) # get the newest result
post_survey = pd.read_csv(filename[0])
pre_survey = pd.read_csv(glob.glob(os.path.join(rootpath, 'data', 'SAD_Consent_form_June 3*.csv'))[0])

# guilt
filename_pattern = re.compile(r'.*interaction_task_2024-0[4-5]-\d{2}_\d{2}h\d{2}\.\d{2}\.\d{3}.csv')
dfs_guilt = []
# filename_guilt = glob.glob(os.path.join(rootpath, 'Data', 'pilot_data_cor', '*_interaction_task_2024-04-(09|10|11|12)_*.csv'))
filename_guilt = [f for f in glob.glob(os.path.join(rootpath, 'data', '*')) if filename_pattern.match(f)]
# read in the data according to the filename
for f in filename_guilt:
    try:
        dfs_guilt.append(pd.read_csv(f))
    except:
        print(f"Error occur when loading:{f}")

# trait
dfs_trait = []
filename_pattern = re.compile(r'.*face_trait_task_2024-0[4-5]-\d{2}_\d{2}h\d{2}\.\d{2}\.\d{3}.csv')
filename_trait = [f for f in glob.glob(os.path.join(rootpath, 'data', '*')) if filename_pattern.match(f)]
for f in filename_trait:
    try:
        dfs_trait.append(pd.read_csv(f))
    except:
        print(f"Error occur when loading:{f}")

# show
post_survey.head()
# guilt.head()
# trait.head()

# error: R_5hxKsNO5XO12p1S_interaction_task_2024-04-16_15h55.15.972.csv - this file is empty
# Out:
# Error occur when loading:/Users/xmr./Desktop/YESLab-RA-training/Data_cleaning/data/R_2Yw6CLfRrTOnl9T_interaction_task_2024-05-01_12h14.15.669.csv
# Error occur when loading:/Users/xmr./Desktop/YESLab-RA-training/Data_cleaning/data/R_3M5652CeCd8fija_interaction_task_2024-05-26_21h16.33.302.csv
# Error occur when loading:/Users/xmr./Desktop/YESLab-RA-training/Data_cleaning/data/R_2GqvCEbwlUobL5D_interaction_task_2024-04-01_10h11.50.784.csv
# Error occur when loading:/Users/xmr./Desktop/YESLab-RA-training/Data_cleaning/data/R_5xTgfhZQPc6lLs5_interaction_task_2024-05-23_14h34.24.135.csv
# Error occur when loading:/Users/xmr./Desktop/YESLab-RA-training/Data_cleaning/data/R_3yazS74o2J9DhjO_interaction_task_2024-05-08_14h48.21.396.csv
# Error occur when loading:/Users/xmr./Desktop/YESLab-RA-training/Data_cleaning/data/R_3fw1uyYv6v4ZVJe_interaction_task_2024-05-01_20h54.33.407.csv
# Error occur when loading:/Users/xmr./Desktop/YESLab-RA-training/Data_cleaning/data/R_3hhygsS0eMynJ7H_interaction_task_2024-05-10_11h43.57.465.csv
# Error occur when loading:/Users/xmr./Desktop/YESLab-RA-training/Data_cleaning/data/R_2KyfqZxEJXtBkzL_interaction_task_2024-05-12_11h04.47.428.csv
# Error occur when loading:/Users/xmr./Desktop/YESLab-RA-training/Data_cleaning/data/R_5hxKsNO5XO12p1S_interaction_task_2024-04-16_15h55.15.972.csv
# Error occur when loading:/Users/xmr./Desktop/YESLab-RA-training/Data_cleaning/data/R_3hhygsS0eMynJ7H_interaction_task_2024-05-10_11h46.13.520.csv
# Error occur when loading:/Users/xmr./Desktop/YESLab-RA-training/Data_cleaning/data/R_3UD5wdOXCX53OZr_interaction_task_2024-05-29_00h45.52.170.csv
# Error occur when loading:/Users/xmr./Desktop/YESLab-RA-training/Data_cleaning/data/R_7Yb9Wkvu2ocVDk1_interaction_task_2024-05-08_10h06.54.096.csv
# Error occur when loading:/Users/xmr./Desktop/YESLab-RA-training/Data_cleaning/data/R_71Et5V1BaqiJuoR_face_trait_task_2024-05-01_12h32.53.065.csv
# Error occur when loading:/Users/xmr./Desktop/YESLab-RA-training/Data_cleaning/data/R_1QDhKsN6bYeEr98_face_trait_task_2024-05-27_00h12.38.123.csv
# Error occur when loading:/Users/xmr./Desktop/YESLab-RA-training/Data_cleaning/data/R_2QFSUNvfjhL1zfu_face_trait_task_2024-04-06_23h15.28.030.csv
#                                            StartDate  \
# 0                                         Start Date
# 1  {"ImportId":"startDate","timeZone":"America/Lo...
# 2                                      3/12/24 11:14
# 3                                       3/16/24 2:40
# 4                                       4/1/24 11:12
#
#                                              EndDate                 Status  \
# 0                                           End Date          Response Type
# 1  {"ImportId":"endDate","timeZone":"America/Los_...  {"ImportId":"status"}
# 2                                      3/12/24 11:14             IP Address
# 3                                       3/16/24 2:47             IP Address
# 4                                       4/1/24 11:12             IP Address
#
#                   IPAddress                 Progress    Duration (in seconds)  \
# 0                IP Address                 Progress    Duration (in seconds)
# 1  {"ImportId":"ipAddress"}  {"ImportId":"progress"}  {"ImportId":"duration"}
# 2           169.231.116.246                      100                        8
# 3            70.185.131.238                      100                      417
# 4           169.231.116.246                      100                       17
#
#                   Finished                                       RecordedDate  \
# 0                 Finished                                      Recorded Date
# 1  {"ImportId":"finished"}  {"ImportId":"recordedDate","timeZone":"America...
# 2                     TRUE                                      3/12/24 11:14
# 3                     TRUE                                       3/16/24 2:47
# 4                     TRUE                                       4/1/24 11:12
#
#                  ResponseId                 RecipientLastName  ...  \
# 0               Response ID               Recipient Last Name  ...
# 1  {"ImportId":"_recordId"}  {"ImportId":"recipientLastName"}  ...
# 2         R_3E0mq3k8gbTs4Nl                               NaN  ...
# 3         R_56XnVwlD1ygCT5v                               NaN  ...
# 4         R_5b8MwFRRNvPKmeB                               NaN  ...
#
#                                       liebowitz#2_20  \
# 0  This measure assesses the way that social anxi...
# 1                          {"ImportId":"QID10#2_92"}
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                       liebowitz#2_21  \
# 0  This measure assesses the way that social anxi...
# 1                          {"ImportId":"QID10#2_93"}
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                       liebowitz#2_22  \
# 0  This measure assesses the way that social anxi...
# 1                          {"ImportId":"QID10#2_94"}
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                       liebowitz#2_23  \
# 0  This measure assesses the way that social anxi...
# 1                          {"ImportId":"QID10#2_95"}
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                       liebowitz#2_24  \
# 0  This measure assesses the way that social anxi...
# 1                          {"ImportId":"QID10#2_96"}
# 2                                                NaN
# 3                                                NaN
# 4                                          2 - Often
#
#                                        Q10  \
# 0  What do you think this study was about?
# 1                {"ImportId":"QID13_TEXT"}
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#                                                  Q11  \
# 0  Do you have any feedback that could help us im...
# 1                          {"ImportId":"QID14_TEXT"}
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                   participantID                 SONAid                 id
# 0                 participantID                 SONAid                 id
# 1  {"ImportId":"participantID"}  {"ImportId":"SONAid"}  {"ImportId":"id"}
# 2                           NaN                    NaN                NaN
# 3             R_21BWPLE20uoyM7G                    NaN                NaN
# 4             R_1BWz2lzoHP6Ecym                    NaN                NaN
#
# [5 rows x 128 columns]

# %% [markdown]
# Now, you will see some error messages. Don't worry, it means those data files are empty, which is due to quiting the experiment in the middle or revisiting. We will remove those empty data files.

# %% [markdown]
# ### check sample size

# %%
print(f"participants in guilt: {len(filename_guilt)}, participant in trait: {len(filename_trait)}")
# Out:
# participants in guilt: 146, participant in trait: 123

# %% [markdown]
# ## Pre-survey

# %%
def extract_col(df, colname_pattern):
    """
    Extract columns with the specified pattern from the DataFrame
    """
    # Filter columns based on the specified patterns
    columns_to_select = [col for col in df.columns if any(pattern in col for pattern in colname_pattern)]

    # Create the anxiety DataFrame
    df_out = df[columns_to_select]

    # if df_out.shape[1] < colname_pattern.__len__():
    #     print(f"Warning: Not all columns with the pattern {colname_pattern} are found in the DataFrame")

    # Remove rows where participantID is NaN
    if 'participantID' in df_out.columns:
        df_out = df_out.dropna(subset=['participantID'])
    elif 'SONAid' in df_out.columns:
        df_out = df_out.dropna(subset=['SONAid'])
    elif 'participant' in df_out.columns and df_out.shape[1] < colname_pattern.__len__():
        print(f"{df_out['participant'][0]} has missing columns")

    return df_out

# %%
pre_survey_clean = extract_col(pre_survey, 
                               ['ResponseID', 'SONAid', 'gender', 'gender_5_TEXT', 'age', 'ethnic', 'ethnic_10_TEXT', 
                                'politic', 'politic_5_TEXT', 'education', 'language', 'language_8_TEXT'])
# pre_survey_clean

# %%
pre_survey_clean.head()
# Out:
#                    UserLanguage  \
# 0                 User Language
# 1   {"ImportId":"userLanguage"}
# 18                           EN
# 19                           EN
# 21                           EN
#
#                                              gender  \
# 0   What is your gender identity? - Selected Choice
# 1                               {"ImportId":"QID7"}
# 18                                           Female
# 19                                              NaN
# 21                                           Female
#
#                                         gender_5_TEXT  \
# 0   What is your gender identity? - Other (please ...
# 1                          {"ImportId":"QID7_5_TEXT"}
# 18                                                NaN
# 19                                                NaN
# 21                                                NaN
#
#                                                   age  \
# 0   How old are you? Please indicate your age in y...
# 1                            {"ImportId":"QID5_TEXT"}
# 18                                                NaN
# 19                                                NaN
# 21                                                 19
#
#                                                ethnic  \
# 0   Please specify your ethnic background(s). You ...
# 1                                 {"ImportId":"QID8"}
# 18                                                NaN
# 19                                                NaN
# 21                                              Asian
#
#                                        ethnic_10_TEXT  \
# 0   Please specify your ethnic background(s). You ...
# 1                         {"ImportId":"QID8_10_TEXT"}
# 18                                                NaN
# 19                                                NaN
# 21                                                NaN
#
#                                     politic  \
# 0   Political preferences - Selected Choice
# 1                      {"ImportId":"QID10"}
# 18                                      NaN
# 19                                      NaN
# 21                                 Democrat
#
#                                        politic_5_TEXT  \
# 0   Political preferences - Other (please specify)...
# 1                         {"ImportId":"QID10_5_TEXT"}
# 18                                                NaN
# 19                                                NaN
# 21                                                NaN
#
#                                    education  \
# 0   What is your highest level of education?
# 1                        {"ImportId":"QID9"}
# 18                                       NaN
# 19                                       NaN
# 21               High school (including GED)
#
#                                              language  \
# 0   What is the primary language spoken in your ho...
# 1                                {"ImportId":"QID11"}
# 18                                                NaN
# 19                                                NaN
# 21                             Other (please specify)
#
#                                       language_8_TEXT  \
# 0   What is the primary language spoken in your ho...
# 1                         {"ImportId":"QID11_8_TEXT"}
# 18                                                NaN
# 19                                                NaN
# 21                                         Vietnamese
#
#                        ResponseID                 SONAid
# 0                      ResponseID                 SONAid
# 1   {"ImportId":"QSEDResponseID"}  {"ImportId":"SONAid"}
# 18              R_2QFSUNvfjhL1zfu                 100179
# 19              R_1QmCurp1iHFSiD1                 100179
# 21              R_3C8Ukaz0zylr2e9                 120374

# %% [markdown]
# Although the pre-survey is not fully cleaned, I prefer to keep the first two rows since it contains the question text.

# %% [markdown]
# ## Post-survey

# %%
post_survey_clean = extract_col(post_survey,
                                ['participantID', 'SONAid', 
                                 'SIAS', 'Interaction', 'Audience', 'neg_eva', 'liebowitz'])

# remove the first and second rows
post_survey_clean = post_survey_clean.drop([0, 1])

# %% [markdown]
# ### calculate scores for each scale

# %%
def Que_scores(df, scaleprefix, reverse_coding, rating_scale):
    # input: df by subjects * items
    # output: total score for each subject
    if scaleprefix == 'liebowitz_fear':
        scaleprefix = 'liebowitz#1'
    elif scaleprefix == 'liebowitz_avoidance':
        scaleprefix = 'liebowitz#2'
    # get columns accroding to the prefix
    cols = [col for col in df.columns if scaleprefix in col]
    df_scale = df[cols]
    df_scale_r = pd.DataFrame()
    for col in df_scale.columns:
        # creat $temp$ as a new integer column
        # if the first character is not a number, it will be converted to NaN
        temp = pd.to_numeric(df_scale[col].str[0], errors='coerce')
        # print(temp)

        # if this column need to be reverse coded
        if col.split('_')[-1] in reverse_coding:
            df_scale_r[col] = rating_scale[1] - temp + rating_scale[0]
        else:
            df_scale_r[col] = temp
    # calculate the total score for each subject, ignoring NaN
    total_score = df_scale_r.mean(axis=1 ,skipna=True)
    return total_score

# %%
scaleprefix = ['SIAS', 'Interaction', 'Audience', 'neg_eva', 'liebowitz_fear', 'liebowitz_avoidance']
# you can see the reverse coding information in [doc](correlational_study_method_description.ipynb)
reverse_coding = {'SIAS': ['5', '9', '11'], 
                 'Interaction': ['3', '6', '10', '15'], 
                 'Audience': ['2', '8'],
                 'neg_eva': ['2', '4', '7', '10'],
                 'liebowitz_fear': [], 'liebowitz_avoidance': []}
rating_scale = {
    'SIAS': [0, 4],
    'Interaction': [1,5],
    'Audience': [1,5],
    'neg_eva': [1,5],
    'liebowitz_fear': [0,3],
    'liebowitz_avoidance': [0,3]
}
df_qscores = pd.DataFrame()
for prefix in scaleprefix:
    df_qscores[prefix] = Que_scores(post_survey_clean, prefix, reverse_coding[prefix], rating_scale[prefix])
df_qscores['liebowitz_total'] = (df_qscores['liebowitz_fear'] + df_qscores['liebowitz_avoidance'])/2
df_qscores['participantID'] = post_survey_clean['participantID']

# for each participant, if there are more than one scores missing, remove this participant
df_qscores = df_qscores.dropna()

# %%
df_qscores.head()
# Out:
#         SIAS  Interaction  Audience   neg_eva  liebowitz_fear  \
# 5   2.052632     2.666667  2.818182  2.909091        2.125000
# 9   1.550000     2.933333  2.833333  3.000000        2.208333
# 10  2.000000     2.600000  2.750000  3.090909        1.818182
# 11  1.450000     3.066667  2.916667  2.909091        0.625000
# 12  3.050000     4.266667  5.000000  3.909091        2.000000
#
#     liebowitz_avoidance  liebowitz_total      participantID
# 5              0.750000         1.437500  R_7dS7fGcto4aBF0E
# 9              0.833333         1.520833  R_2dZ82kJ2ybI5Wiu
# 10             1.347826         1.583004  R_1RlIO1DP8koMWuo
# 11             1.416667         1.020833  R_7PyO7Fjqtbjl581
# 12             1.958333         1.979167  R_1hbYZAAG1H7UZQE

# %%
print(f"Now we have {df_qscores.shape[0]} participants that completed the questionnaires")
# Out:
# Now we have 101 participants that completed the questionnaires

# %% [markdown]
# ## Guilt task
# ### Long format
# This step select columns in interests, and excluded those do not have all DVs.

# %%
# Define the patterns to search for
DVname = ['slider_guilt', 'share_slider', 'slider_apology', \
          'slider_hide', 'slider_forgiveness', 'slider_mad']

# Filter columns based on the specified patterns
subject_info = ['participant', 'SONAid', 'date', 'chooserow', \
                     'stipic', 'type_trial', 'DV', \
                     'judge.clicked_name','answer', 'incompleteTrials']

dfs_guilt_clean = []
for df in dfs_guilt:
    df_cleaned = extract_col(df, DVname + subject_info)
    
    # print(f"number of trials: {df_cleaned['chooserow'][0].__len__()}")
    # print(f"shape: {df_cleaned.shape}")

    try:
        if df_cleaned.shape[1] > 18 and df_cleaned.shape[0] > 41: # they should have a total of 42 trials at least
            dfs_guilt_clean.append(df_cleaned)
        else:
            print(f"{df_cleaned['participant'][0]} completed less than 42 trials")
    except:
        print(f"Error: {df_cleaned['date'][0]}")
# Out:
# R_2EGDBl6ai8CWmRz completed less than 42 trials
# R_2KyfqZxEJXtBkzL completed less than 42 trials
# R_5NxBtjFfGZd55iP completed less than 42 trials
# R_7OwUL9VEO13T4Sy completed less than 42 trials
# R_2QFSUNvfjhL1zfu completed less than 42 trials
# R_5KTszjvZUJlIenp completed less than 42 trials
# R_1BWz2lzoHP6Ecym completed less than 42 trials
# R_3HGNQtHAhV6oD0K completed less than 42 trials
# R_5xTgfhZQPc6lLs5 completed less than 42 trials
# R_7hZmoK1t3s8IgkC completed less than 42 trials
# R_3VfGmN3kRO9xCTg completed less than 42 trials
# R_4dz2AQUg82nrh9r completed less than 42 trials
# R_3C8Ukaz0zylr2e9 completed less than 42 trials
# R_1MJr8NKNf8pAoJV completed less than 42 trials
# R_1g62pACNcXR9tqu completed less than 42 trials
# R_3P7RFUUGxBU9T3j completed less than 42 trials
# R_1QmCurp1iHFSiD1 completed less than 42 trials

# %% [markdown]
# Now we transform wide format to long format. Put all DVs in one column.

# %%
def raw2long(df, 
              keep_columns = [], 
              DVname = [], 
              have_attention_check = False, check_missing = False, 
              drop_according = ''):
    """
    Convert the DataFrame from wide to long format
    """
    # print(f"Participant {df['participant'][0]}")

    # if a column is missing according to keep_columns, add it
    for col in keep_columns:
        if col not in df.columns:
            df[col] = np.nan
    # return df
    
    selectrow = df[keep_columns + [col + '.response' for col in DVname] + [col + '.rt' for col in DVname]]
    # print(selectrow.columns)

    # for guilt task, calculate accuracy in attention check
    # attention check: compare judge.clicked_name and answer if answer is not 'No answer'
    if have_attention_check:
        attention_check = selectrow.dropna(subset=['answer']).query("answer == 'RightButton' or answer == 'LeftButton'")
        acc = np.mean(attention_check['judge.clicked_name'] == attention_check['answer'])
        if acc > 0.8:
            print(f"Participant {selectrow['participant'][0]} acc = {acc}")
        else:
            print(f"Participant {selectrow['participant'][0]} acc = {acc} < 0.8 *****")
            return None # remove this participant
    
    if check_missing:
        missed_trials = selectrow['incompleteTrials'].dropna().values
        if len(missed_trials)>0:
            print(f"    Missed trials: {missed_trials}")

    # # Melt the DataFrame to convert it to long format
    df_long = pd.melt(selectrow, 
                    id_vars=keep_columns, 
                    value_vars=[col + '.response' for col in DVname] + [col + '.rt' for col in DVname],
                    var_name='DV_type',
                    value_name='DV_value')

    # Extract DV from DV_type
    df_long['DV_name'] = df_long['DV_type'].apply(lambda x: x.split('.')[0])

    # Extract rt or response from DV_type
    df_long['DV_resptype'] = df_long['DV_type'].apply(lambda x: 'rt' if 'rt' in x else 'response')

    # clean for non stimuli
    # print(drop_according)
    df_long = df_long.dropna(subset=[drop_according])

    return df_long

# %%
import numpy as np

# start converting to long format
dfs_guilt_long = []
for df in dfs_guilt_clean:
    dftolong = raw2long(df, 
                        keep_columns=subject_info,
                        DVname=DVname,
                        have_attention_check = True, 
                        check_missing = True, 
                        drop_according='stipic')
    # check if the return is None
    if dftolong is not None:
        dfs_guilt_long.append(dftolong)
    # print(f"Participant {df['participant'][0]}")

# dfs_guilt_long.__len__() # 8 valid participants
# Out:
# Participant R_10kpEEzjRy8xPwe acc = 1.0
# Participant R_1g31aXiXPgtLRgR acc = 1.0
# Participant R_5N39wPdNP63q03G acc = 1.0
# Participant R_7PyO7Fjqtbjl581 acc = 1.0
# Participant R_7CKs9SKBixkdv7M acc = 0.5 < 0.8 *****
# Participant R_1QDhKsN6bYeEr98 acc = 1.0
# Participant R_1JOTZSNdzRD5obR acc = 1.0
# Participant R_7U9hZc6iX0aCxva acc = 1.0
# Participant R_5WYyGOzXtwowWQ4 acc = 1.0
# Participant R_1FQhiEgg2BqpONz acc = 1.0
# Participant R_3S8p45ndEmC6VLP acc = 1.0
#     Missed trials: [107.]
# Participant R_5uP9JJsaCJo6OOz acc = 1.0
# Participant R_7m3jTTuD6pGKm7S acc = 1.0
# Participant R_1hbYZAAG1H7UZQE acc = 1.0
#     Missed trials: [16.]
# Participant R_3g0YlMh4uWQIm91 acc = 1.0
# Participant R_12tSZmx8hSuXu6d acc = 1.0
#     Missed trials: [103. 124.]
# Participant R_1dEQmznFrOUMB26 acc = 1.0
# Participant R_2imqlVYkXvGkEUD acc = 1.0
#     Missed trials: [125.]
# Participant R_3zJ5QiBCzzLGrFb acc = 1.0
#     Missed trials: [172.   4.]
# Participant R_3HGNQtHAhV6oD0K acc = 0.3333333333333333 < 0.8 *****
# Participant R_5CTfFYNxQEuWapL acc = 0.5 < 0.8 *****
# Participant R_2KyfqZxEJXtBkzL acc = 1.0
# Participant R_1Et4aI0weGQGovt acc = 1.0
# Participant R_5ZUNCbLeFy8Pq4V acc = 1.0
#     Missed trials: [188.]
# Participant R_1lghUhjTVIzEwwh acc = 1.0
#     Missed trials: [36.]
# Participant R_3c8LrmXWaYdFGlX acc = 1.0
# Participant R_49GRi7W6rJG5j6F acc = 0.0 < 0.8 *****
# Participant R_7dZ8IU3hLSkW652 acc = 1.0
# Participant R_1g62pACNcXR9tqu acc = 1.0
#     Missed trials: [92. 11.]
# Participant R_2R6CcD6FyRm7qDv acc = 1.0
# Participant R_75PkJGK4ZpN5clP acc = 0.6666666666666666 < 0.8 *****
# Participant R_3I4v4hVO3BKl5to acc = 0.5 < 0.8 *****
# Participant R_8cvY6RMpIIbMEo3 acc = 1.0
# Participant R_1m1uzN8R2BXv7GO acc = 1.0
# Participant R_7VPVdZSfqq3ow3V acc = 0.5 < 0.8 *****
# Participant R_2Pz1ESHNLhmVqlq acc = 1.0
# Participant R_5BbMyj9NaP7q9xv acc = 0.5 < 0.8 *****
# Participant R_3rOQiJSaYzSrL8h acc = 1.0
#     Missed trials: [30.]
# Participant R_5jfA4GJL7XpO7KM acc = 1.0
# Participant R_3JqODn0dO2tMalP acc = 1.0
# Participant R_2KryIkmTCOb6eUU acc = 1.0
# /var/folders/2s/8dgsnn3n2js9x33j5_1lyth40000gn/T/ipykernel_11343/3066940952.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = np.nan
# Participant R_1FEbkzkWgC4zflT acc = 0.5 < 0.8 *****
# Participant R_79c3LNBLwbOBa08 acc = 1.0
# Participant R_6JCnE5DyshtV1nw acc = 1.0
# Participant R_3ekubxwa9Ik5zUP acc = 1.0
# Participant R_15ZREkpd1fiWnv8 acc = 1.0
#     Missed trials: [183. 153. 162.]
# Participant R_5Oxl4uaiGfTi56L acc = 0.5 < 0.8 *****
# Participant R_5C4do3eNoyYdAul acc = 1.0
#     Missed trials: [72.]
# Participant R_5rCBwHBJTpvkpb3 acc = 1.0
#     Missed trials: [66.]
# Participant R_2dZ82kJ2ybI5Wiu acc = 1.0
# Participant R_1m9l4nPkPn7qKin acc = 0.0 < 0.8 *****
# Participant R_23fCGTf5Bw4sfo3 acc = 1.0
#     Missed trials: [ 70. 142. 109.  65.]
# Participant R_5fVxDGEG0OvT1TP acc = 1.0
#     Missed trials: [85.]
# Participant R_7lxhI87CHabQjfc acc = 1.0
# Participant R_5lSB76siDkwnBL3 acc = 1.0
#     Missed trials: [109.]
# Participant R_1lh2G802tSwgxMU acc = 1.0
#     Missed trials: [ 45. 145. 108. 191. 164. 164.]
# Participant R_2M3BSrq6ZzSs0t3 acc = 1.0
#     Missed trials: [104. 182.]
# Participant R_61d7Su0GZhtK1nx acc = 0.0 < 0.8 *****
# Participant R_6upvmTfOk884ujf acc = 1.0
#     Missed trials: [125. 182. 146.  78.  50.]
# Participant R_3DwBYBdZzedqc9v acc = 1.0
#     Missed trials: [172.  42.]
# Participant R_7smoBYcMfiEmyTu acc = 0.3333333333333333 < 0.8 *****
# Participant R_68i7aYrs5yFNwB3 acc = 1.0
#     Missed trials: [111.  89.]
# Participant R_5EccKcotuRFOO33 acc = 1.0
# Participant R_3Hq0pKoFXUeyfKX acc = 1.0
# Participant R_1lsKKVQpKnRQfFs acc = 1.0
# Participant R_1EYAm4n1kovKRIe acc = 0.5 < 0.8 *****
# Participant R_7MgMIvXrLYayfkt acc = 1.0
# Participant R_5gBJYH1TXEzkJ8L acc = 1.0
#     Missed trials: [88.]
# Participant R_3FJcVxSy2lNvUyM acc = 1.0
#     Missed trials: [ 61. 148.]
# Participant R_73JC3XxCdLeJrlD acc = 1.0
#     Missed trials: [116.  81.]
# Participant R_1QYUgALf2MKc3vp acc = 1.0
# Participant R_3hlnjdAbx50vJ5l acc = 1.0
# Participant R_71Et5V1BaqiJuoR acc = 1.0
#     Missed trials: [167.]
# Participant R_7PRxMH8tgtcALpe acc = 1.0
# Participant R_3NHYjetBGepYbrK acc = 1.0
#     Missed trials: [ 99. 178.  82.]
# Participant R_7PpRpKeBBPUcMUJ acc = 1.0
# Participant R_13m40r672zQl4g7 acc = 1.0
#     Missed trials: [83.]
# Participant R_1JeBbwgNmS1aKcb acc = 1.0
# Participant R_1YUzjPBvYVnwzBL acc = 1.0
#     Missed trials: [89.]
# Participant R_7mRgBYfm8mjMQG1 acc = 1.0
# Participant R_1Jreilcdud9HMuf acc = 1.0
#     Missed trials: [156. 110. 153. 176. 186.  78. 141.]
# Participant R_3WksQ064xj6JYYN acc = 1.0
#     Missed trials: [187.]
# Participant R_3YovKuFHnYI49gt acc = 1.0
#     Missed trials: [191.  33. 112.   6.  69.  83.]
# Participant R_7LzE0pjYtdObtSm acc = 1.0
#     Missed trials: [55. 93. 90.]
# Participant R_3bNMAkMCLdBCePj acc = 0.5 < 0.8 *****
# Participant R_6ef1Z01PGngUI9H acc = 0.0 < 0.8 *****
# Participant R_6qDGpWVB0cADqOv acc = 1.0
#     Missed trials: [135.]
# Participant R_701Ahvlhq3udAHc acc = 0.5 < 0.8 *****
# Participant R_1FlaYCokradBQ0u acc = 1.0
# Participant R_742eAVEWlciGtQU acc = 1.0
# Participant R_5NFLSVTrP1bwEtb acc = 1.0
#     Missed trials: [ 77.  75.  62. 124.  71.  71.]
# Participant R_3Vxfev3MGsXgbK1 acc = 1.0
# Participant R_6FVQ6tVpIriVaju acc = 1.0
#     Missed trials: [143.]
# Participant R_3z8wN509TuVnNc6 acc = 1.0
# Participant R_1WtVKNu6flh5Sp7 acc = 1.0
# Participant R_2D6PXoNGiJXqobD acc = 1.0
#     Missed trials: [141.]
# Participant R_59nXN3KJnjYkf8b acc = 1.0
# Participant R_2ewvKYOw2lIyB6E acc = 1.0
# Participant R_3kN6FWJDmiyDkpx acc = 1.0
# Participant R_5lzc9Eh9N9dRLuJ acc = 1.0
# Participant R_3VjvlLbPe9t3xLs acc = 0.5 < 0.8 *****
# Participant R_37HoYLt2WoBiFYl acc = 1.0
#     Missed trials: [67.]
# Participant R_31XdkdkFfWXTP68 acc = 0.5 < 0.8 *****
# Participant R_809hAgXHcl3WkRr acc = 1.0
#     Missed trials: [177.  91. 130. 117.]
# Participant R_6It1un8kGFdY7i4 acc = 0.0 < 0.8 *****
# Participant R_54voFul3k9D7bqr acc = 1.0
# Participant R_5LgU1eXqKtcFTuL acc = 1.0
#     Missed trials: [122. 160.]
# Participant R_7CKHJGMjptgL6SO acc = 1.0
#     Missed trials: [126.]
# Participant R_31BwcmFMmY8Wg3q acc = 1.0
# Participant R_5SxAnX25qTwpM5H acc = 0.5 < 0.8 *****
# Participant R_1RlIO1DP8koMWuo acc = 0.6666666666666666 < 0.8 *****
# Participant R_53TWARpLPmUzLYZ acc = 1.0
# Participant R_7eap0FQxb1TrCnY acc = 1.0
# Participant R_7dS7fGcto4aBF0E acc = 0.0 < 0.8 *****
# Participant R_1siyZPsGPt63FbT acc = 1.0
# Participant R_5PyR4YVF9PC296x acc = 1.0
# Participant R_1q8WSTNQENILdNT acc = 0.5 < 0.8 *****
# /var/folders/2s/8dgsnn3n2js9x33j5_1lyth40000gn/T/ipykernel_11343/3066940952.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = np.nan

# %%
# check guilt participants
print(f"Now we have {len(dfs_guilt_long)} participants in guilt task")
# Out:
# Now we have 93 participants in guilt task

# %% [markdown]
# ### Guilt: wide format

# %%
def long2wide(df_long, DVtype):
    """
    convert long format data to wide format
    """
    # Filter rows with non-NA values and specific trial type and DV type
    thisDVtype = DVtype + '.response'
    filtered_df = df_long.dropna(subset=['DV_value']).query("(type_trial == 1 and DV_type == @thisDVtype) or (type_trial == 3 and DV_type == @thisDVtype)")
    
    # Calculate the mean value across rows
    mean_value = filtered_df.groupby('type_trial')['DV_value'].mean().reset_index()
    diff_value = mean_value.loc[mean_value['type_trial'] == 3]['DV_value'].values[0] - mean_value.loc[mean_value['type_trial'] == 1]['DV_value'].values[0]
    # diff_value = mean_value.loc['type_trial'==3]['DV_value'] - mean_value.loc['type_trial' == 1]['DV_value']
    # change 'DV_value' to thisDVtype
    # diff_value = diff_value.rename(columns={'DV_value': thisDVtype.split('.')[0]+'_diff'})

    result = {DVtype+'_both_incor': mean_value.loc[mean_value['type_trial'] == 1]['DV_value'].values[0],
              DVtype+'_self_incor': mean_value.loc[mean_value['type_trial'] == 3]['DV_value'].values[0],
              DVtype+'_diff': diff_value}

    return result

# %%
df_wide = pd.DataFrame()

for df in dfs_guilt_long:
    this_df = pd.DataFrame()

    # save subject_info
    thisSubInfo = df[['participant', 'SONAid']].iloc[0]
    # temp = thisSubInfo['participant']
    this_df.loc[0, 'participant'] = thisSubInfo['participant']
    this_df.loc[0, 'SONAid'] = thisSubInfo['SONAid']
    # print(this_df)

    for DVtype in DVname:
        dv_diff = long2wide(df, DVtype= DVtype)
        # dv_name = DVtype + '_diff'
        # this_df.loc[0, dv_name] = dv_diff
        # this_df = pd.merge(this_df, this_dv_df, on=['type_trial'], how='outer')
        for key, value in dv_diff.items():
            this_df.loc[0, key] = value
    
    # print(this_df)

    # put into a large df
    df_wide = pd.concat([df_wide, this_df], axis=0)

# df_wide['condition'] = df_wide['type_trial'].apply(lambda x: 'both_incor' if x == 1 else 'self_incor')

# %%
df_wide.head()
# Out:
#          participant    SONAid  slider_guilt_both_incor  \
# 0  R_10kpEEzjRy8xPwe  120226.0                60.000000
# 0  R_1g31aXiXPgtLRgR  120256.0                 0.666667
# 0  R_5N39wPdNP63q03G  120390.0                13.333333
# 0  R_7PyO7Fjqtbjl581  120529.0                96.333333
# 0  R_1QDhKsN6bYeEr98  120753.0               100.000000
#
#    slider_guilt_self_incor  slider_guilt_diff  share_slider_both_incor  \
# 0                59.666667          -0.333333                 3.982993
# 0                32.000000          31.333333                 4.982754
# 0                35.666667          22.333333                 2.489887
# 0                87.666667          -8.666667                 4.317009
# 0                96.666667          -3.333333                 3.831299
#
#    share_slider_self_incor  share_slider_diff  slider_apology_both_incor  \
# 0                 3.665533          -0.317460                  57.333333
# 0                 4.977548          -0.005206                  46.666667
# 0                 2.474501          -0.015386                  20.000000
# 0                 3.347475          -0.969534                  86.666667
# 0                 4.650391           0.819092                 100.000000
#
#    slider_apology_self_incor  slider_apology_diff  slider_hide_both_incor  \
# 0                  37.666667           -19.666667               70.666667
# 0                  49.333333             2.666667                7.000000
# 0                  33.000000            13.000000               17.000000
# 0                  96.666667            10.000000               33.333333
# 0                 100.000000             0.000000               26.333333
#
#    slider_hide_self_incor  slider_hide_diff  slider_forgiveness_both_incor  \
# 0               90.666667         20.000000                      66.399826
# 0               20.000000         13.000000                      82.907496
# 0               23.333333          6.333333                      40.976168
# 0               53.333333         20.000000                      62.838407
# 0               28.000000          1.666667                      45.700093
#
#    slider_forgiveness_self_incor  slider_forgiveness_diff  \
# 0                      59.757438                -6.642388
# 0                      82.986375                 0.078879
# 0                      39.928363                -1.047804
# 0                      63.571077                 0.732670
# 0                      28.887727               -16.812366
#
#    slider_mad_both_incor  slider_mad_self_incor  slider_mad_diff
# 0              58.749628              43.495041       -15.254587
# 0               8.573104              12.438390         3.865285
# 0              26.068410              29.855412         3.787002
# 0              59.933817              66.761349         6.827532
# 0              83.068313              91.796546         8.728233

# %% [markdown]
# ### Correlation between DVs and social anxiety

# %%
from scipy.stats import pearsonr

dv_diff = ['slider_guilt_diff', 'share_slider_diff', 'slider_apology_diff', 'slider_hide_diff', 'slider_forgiveness_diff', 'slider_mad_diff']
scaleprefix2 = scaleprefix + ['liebowitz_total']

# only include participants who is in df_wide['participant']
df_qscores_excluded = df_qscores[df_qscores['participantID'].isin(df_wide['participant'])]
df_wide = df_wide[df_wide['participant'].isin(df_qscores_excluded['participantID'])]
print(f"Number of participants in df_wide: {df_wide['participant'].unique().__len__()}, in df_qscores_excluded: {df_qscores_excluded['participantID'].unique().__len__()}")

# sort df_wide and df_qscores_excluded to make sure the participantID is in the same order
df_wide = df_wide.sort_values(by='participant')
df_qscores_excluded = df_qscores_excluded.sort_values(by='participantID')

for scale in scaleprefix2:
    print(f"Scale: {scale}")
    # calculate correlation between df_wide['slider_guilt_diff'] and df_qscores_excluded['SIAS']
    for dv in dv_diff:
        [r, p] = pearsonr(df_wide[dv], df_qscores_excluded[scale])
        marker = '*' if p < 0.05 else ''
        print(f"    {dv} and {scale}: {r:.3}, p-value: {p:.3}{marker}")

# concatenate the two DataFrames
df_wide_q = pd.concat([df_wide.reset_index(drop=True), df_qscores_excluded.reset_index(drop=True)], axis=1)
# Out:
# Number of participants in df_wide: 81, in df_qscores_excluded: 81
# Scale: SIAS
#     slider_guilt_diff and SIAS: -0.0821, p-value: 0.466
#     share_slider_diff and SIAS: -0.0155, p-value: 0.891
#     slider_apology_diff and SIAS: -0.207, p-value: 0.0634
#     slider_hide_diff and SIAS: 0.0107, p-value: 0.924
#     slider_forgiveness_diff and SIAS: -0.148, p-value: 0.188
#     slider_mad_diff and SIAS: 0.0952, p-value: 0.398
# Scale: Interaction
#     slider_guilt_diff and Interaction: -0.00332, p-value: 0.977
#     share_slider_diff and Interaction: 0.0231, p-value: 0.838
#     slider_apology_diff and Interaction: -0.0922, p-value: 0.413
#     slider_hide_diff and Interaction: 0.001, p-value: 0.993
#     slider_forgiveness_diff and Interaction: -0.117, p-value: 0.299
#     slider_mad_diff and Interaction: 0.174, p-value: 0.121
# Scale: Audience
#     slider_guilt_diff and Audience: -0.0247, p-value: 0.827
#     share_slider_diff and Audience: -0.00638, p-value: 0.955
#     slider_apology_diff and Audience: -0.16, p-value: 0.153
#     slider_hide_diff and Audience: -0.004, p-value: 0.972
#     slider_forgiveness_diff and Audience: 0.033, p-value: 0.77
#     slider_mad_diff and Audience: 0.0187, p-value: 0.868
# Scale: neg_eva
#     slider_guilt_diff and neg_eva: 0.0381, p-value: 0.736
#     share_slider_diff and neg_eva: 0.0442, p-value: 0.695
#     slider_apology_diff and neg_eva: -0.157, p-value: 0.162
#     slider_hide_diff and neg_eva: 0.0778, p-value: 0.49
#     slider_forgiveness_diff and neg_eva: -0.152, p-value: 0.177
#     slider_mad_diff and neg_eva: 0.0891, p-value: 0.429
# Scale: liebowitz_fear
#     slider_guilt_diff and liebowitz_fear: -0.182, p-value: 0.104
#     share_slider_diff and liebowitz_fear: -0.0829, p-value: 0.462
#     slider_apology_diff and liebowitz_fear: -0.283, p-value: 0.0104*
#     slider_hide_diff and liebowitz_fear: 0.0512, p-value: 0.65
#     slider_forgiveness_diff and liebowitz_fear: 0.0717, p-value: 0.525
#     slider_mad_diff and liebowitz_fear: -0.0199, p-value: 0.86
# Scale: liebowitz_avoidance
#     slider_guilt_diff and liebowitz_avoidance: -0.115, p-value: 0.307
#     share_slider_diff and liebowitz_avoidance: -0.147, p-value: 0.189
#     slider_apology_diff and liebowitz_avoidance: -0.186, p-value: 0.0963
#     slider_hide_diff and liebowitz_avoidance: -0.0646, p-value: 0.566
#     slider_forgiveness_diff and liebowitz_avoidance: 0.0416, p-value: 0.712
#     slider_mad_diff and liebowitz_avoidance: -0.027, p-value: 0.811
# Scale: liebowitz_total
#     slider_guilt_diff and liebowitz_total: -0.16, p-value: 0.154
#     share_slider_diff and liebowitz_total: -0.12, p-value: 0.287
#     slider_apology_diff and liebowitz_total: -0.253, p-value: 0.0228*
#     slider_hide_diff and liebowitz_total: -0.00267, p-value: 0.981
#     slider_forgiveness_diff and liebowitz_total: 0.0613, p-value: 0.587
#     slider_mad_diff and liebowitz_total: -0.0246, p-value: 0.827

# %% [markdown]
# ### Visualization: scatter plot between social anxiety scale and each dv

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
condtype = ['_both_incor', '_self_incor', '_diff']
for cond in condtype:
    # calculate scaleprefix2 and DVname correlation
    select_col = scaleprefix2 + [dv+cond for dv in DVname]
    # calculate the correlation matrix
    corrmax = df_wide_q[select_col].corr()
    plt.figure(figsize=(12, 12))
    # draw the heatmap, set color when r=0 to white
    sns.heatmap(corrmax, annot=True, fmt=".2f", cmap='coolwarm', center=0, vmin=-1, vmax=1)
    # add a title
    plt.title('Correlation Matrix: ' + cond[1:])
    plt.show()

# %% [markdown]
# By inspectation, we found that some DVs (guilt, apology, hide, mad) are correlated with almost all social anxiety questionnaires under the both_incor condition. Now we will draw scatter plots to visualize the relationship between all DVs and a sample questionnaire-negetive evaluation.

# %%
# plot the correlation between each dv and questionnaires
figure, axes = plt.subplots(2, 3, figsize=(15, 10))
dv_both_incor = [dv+'_both_incor' for dv in DVname]
for i, dv in enumerate(dv_both_incor):
    sns.regplot(y=dv, x='neg_eva', data=df_wide_q, ax=axes[i//3, i%3])
    axes[i//3, i%3].set_title(f"{dv} and negative evaluation")
    # compute the correlation and significance level and put it on the plot
    [r, p] = pearsonr(df_wide_q[dv], df_wide_q['neg_eva'])
    axes[i//3, i%3].text(0.1, 0.9, f"r={r:.3}, p={p:.3}", transform=axes[i//3, i%3].transAxes)
plt.tight_layout()

# How about the correlation between each dv under the condition of self_incor and SIAS?
figure, axes = plt.subplots(2, 3, figsize=(15, 10))
dv_self_incor = [dv+'_self_incor' for dv in DVname]
for i, dv in enumerate(dv_self_incor):
    sns.regplot(y=dv, x='SIAS', data=df_wide_q, ax=axes[i//3, i%3])
    axes[i//3, i%3].set_title(f"{dv} and SIAS")
    # compute the correlation and significance level and put it on the plot
    [r, p] = pearsonr(df_wide_q[dv], df_wide_q['SIAS'])
    axes[i//3, i%3].text(0.1, 0.9, f"r={r:.3}, p={p:.3}", transform=axes[i//3, i%3].transAxes)
plt.tight_layout()

# # plot the correlation between each dv and liebowitz
# figure, axes = plt.subplots(2, 3, figsize=(15, 10))
# for i, dv in enumerate(dv_diff):
#     sns.regplot(y=dv, x='liebowitz_total', data=df_wide_q, ax=axes[i//3, i%3])
#     axes[i//3, i%3].set_title(f"{dv} and liebowitz_total")

# %% [markdown]
# ### Visualization: violin plot by condition

# %% [markdown]
# ### TODO
# - Thanks for Hongyu's suggestion. Now, please write code to check the distribution of each DV by condition. You can draw histogram of each DV and put all three conditions in one plot for comparison.
# - Visualize the difference of each DV under different conditions. You can use violin plot that shown below for visualization, or try other types of plots. To test the significance of difference, you can use ANOVA or mixed effect model (put participants as random intercept).

# %%
# visualize the data
import matplotlib.pyplot as plt
import seaborn as sns

# draw violin plot for each DV in 'both_incor' and 'self_incor' and '_diff', according to df_wide
for dv in DVname:
    # get the ylim
    ylim = df_wide[[dv+'_both_incor', dv+'_self_incor', dv+'_diff']].min().min(), df_wide[[dv+'_both_incor', dv+'_self_incor', dv+'_diff']].max().max()
    ylim = (ylim[0]-(ylim[1]-ylim[0])/10, ylim[1]+(ylim[1]-ylim[0])/10)

    plt.figure()
    # create a 1*3 subplot
    plt.subplot(1, 3, 1)
    sns.violinplot(y=dv+'_both_incor', data=df_wide)
    plt.title(f'{dv} both_incor')
    plt.ylim(ylim)

    plt.subplot(1, 3, 2)
    sns.violinplot(y=dv+'_self_incor', data=df_wide)
    plt.title(f'{dv} self_incor')
    plt.ylim(ylim)

    plt.subplot(1, 3, 3)
    sns.violinplot(y=dv+'_diff', data=df_wide)
    plt.title(f'{dv} diff')
    plt.ylim(ylim)
    plt.show()

# %% [markdown]
# ## Facial trait task

# %%
def raw2long_trait(df, 
                   keep_columns=[],
                   DVname=[], 
                   have_attention_check=False, 
                   check_missing=False, 
                   drop_according=''):
    """
    Convert the DataFrame from wide to long format
    """
    # select columns
    colinterest = keep_columns + [col + '.response' for col in DVname] + [col + '.rt' for col in DVname]
    for col in colinterest:
        if col not in df.columns:
            df[col] = np.nan
    selectrow = df[colinterest]

    if have_attention_check:
        attention_check = selectrow.dropna(subset=['isCheck']).query("isCheck == 1")
        if attention_check['answer'].notnull().any():
            # in one version of this experiment, the answer is a random number
            acc = np.mean(np.logical_and(attention_check['slider_face_judge.response'] > attention_check['answer']-0.5,
                                         attention_check['slider_face_judge.response'] < attention_check['answer']+0.5))
        elif attention_check['isCheck'].notnull().any():
            # in one version of this experiment, we set the answer as 5
            acc = np.mean(np.logical_and(attention_check['slider_face_judge.response'] > 5-0.5,
                                         attention_check['slider_face_judge.response'] < 5+0.5))
        else:
            # in the early version of this experiment, there's no attention check
            acc = None

        if acc is None or acc < 0.8:
            if not selectrow.empty and 'participant' in selectrow.columns:
                print(f"Participant {selectrow['participant'].iloc[0]} acc = {acc} < 0.8 *****")
            df_long = []
            return df_long   

    session_trait = []
    if check_missing:
        if selectrow['slider_judge_img'].notnull().any():
            session_trait = [x for x in selectrow['slider_judge_img'].unique() if x is not np.nan]

    if len(session_trait) > 3: 
        if selectrow['isCheck'].notnull().any():
            df_long = selectrow.dropna(subset=[drop_according]).query('isCheck==0')
        else:
            df_long = selectrow.dropna(subset=[drop_according])
        
        if df_long.shape[0] == 200:
            df_long.loc[:49, 'slider_judge_img'] = session_trait[0]
            df_long.loc[50:99, 'slider_judge_img'] = session_trait[1]
            df_long.loc[100:149, 'slider_judge_img'] = session_trait[2]
            df_long.loc[150:, 'slider_judge_img'] = session_trait[3]
            df_long = df_long.dropna(subset=['slider_face_judge.response'])
            df_long = df_long.query('`slider_face_judge.rt` > 0.2 and `slider_face_judge.rt` < 10')
        else:
            print(f"Participant {df_long['participant'].iloc[0]} has less than 200 trials")
            df_long = []
    else:
        df_long = []

    return df_long

# %%
sub_info = ['participant', 'SONAid', 'face_serial', 'isCheck', 'answer', \
            'session_serial', 'slider_judge_img', 'image_name']
exp_info = ['slider_face_judge']

# facial trait task
dfs_long = pd.DataFrame()
for df in dfs_trait:
    # Now we don't exlude any participants according to their performance in attention check
    df_long = raw2long_trait(df, 
                             keep_columns=sub_info,
                             DVname = exp_info,
                             have_attention_check = False, 
                             check_missing = True, 
                             drop_according='image_name')
    if len(df_long) > 0:
        dfs_long = dfs_long.append(df_long)
# Out:
# /Users/xmr./opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# /Users/xmr./opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# Participant R_5pSuadkN58kbdOq has less than 200 trials
# Participant R_1BWz2lzoHP6Ecym has less than 200 trials

# %%
# dfs_long['participant'].unique().__len__()
print(f"Number of participants in facial trait task: {dfs_long['participant'].unique().__len__()}")
# Out:
# Number of participants in facial trait task: 105

# %% [markdown]
# ### transform to wide format

# %%
def long2wide_trait(df_long):
    # drop non response rows
    # df_long = df_long.dropna(subset=['slider_face_judge.response'])
    df_long.loc[:, 'trait'] = df_long['slider_judge_img'].apply(lambda x: x.split('.')[0])
    # calcualte the mean value for each trait
    df_long_mean = df_long.groupby(['participant', 'trait'])['slider_face_judge.response'].mean().reset_index()

    # convert long format data to wide format for facial trait task and calculate the mean value for each trait
    df_wide = df_long_mean.pivot(index='participant', 
                            columns='trait', 
                            values='slider_face_judge.response').reset_index()
    # print(df_wide.head(5))

    return df_wide

# %%
df_wide_trait = long2wide_trait(dfs_long)

# %%
df_wide_trait.head()
# Out:
# trait        participant  competent  critical  friendly  trustworthy
# 0      R_10kpEEzjRy8xPwe   5.119275  4.113043  4.167297     4.055992
# 1      R_12tSZmx8hSuXu6d   5.362653  4.608921  3.908934     4.030238
# 2      R_13m40r672zQl4g7   3.652886  3.119623  3.655737     4.158338
# 3      R_15ZREkpd1fiWnv8   4.053333  3.885037  4.380278     3.960000
# 4      R_1EYAm4n1kovKRIe   4.787635  3.947183  3.991461     4.702853

# %% [markdown]
# ### correlation between social anxiety and critical judgment

# %%
# find the common participants in df_wide_trait and df_qscores_excluded
df_wide_trait = df_wide_trait[df_wide_trait['participant'].isin(df_qscores['participantID'])]
df_qscores_excluded2 = df_qscores[df_qscores['participantID'].isin(df_wide_trait['participant'])]
print(f"Number of participants in df_wide_trait: {df_wide_trait['participant'].unique().__len__()}, in df_qscores_excluded2: {df_qscores_excluded2['participantID'].unique().__len__()}")

# rank
df_wide_trait = df_wide_trait.sort_values(by='participant')
df_qscores_excluded2 = df_qscores_excluded2.sort_values(by='participantID')
# Out:
# Number of participants in df_wide_trait: 99, in df_qscores_excluded2: 99

# %%
# correlation between facial trait and questionnaire
for scale in scaleprefix:
    print(f"Scale: {scale}")
    for trait in df_wide_trait.columns[1:]:
        [r, p] = pearsonr(df_wide_trait[trait], df_qscores_excluded2[scale])
        marker = '*' if p < 0.05 else ''
        print(f"    {trait} and {scale}: {r:.3}, p-value: {p:.3}{marker}")
# Out:
# Scale: SIAS
#     competent and SIAS: 0.103, p-value: 0.309
#     critical and SIAS: 0.164, p-value: 0.104
#     friendly and SIAS: 0.0983, p-value: 0.333
#     trustworthy and SIAS: 0.00162, p-value: 0.987
# Scale: Interaction
#     competent and Interaction: 0.152, p-value: 0.132
#     critical and Interaction: 0.231, p-value: 0.0216*
#     friendly and Interaction: 0.12, p-value: 0.236
#     trustworthy and Interaction: 0.0078, p-value: 0.939
# Scale: Audience
#     competent and Audience: 0.11, p-value: 0.278
#     critical and Audience: 0.226, p-value: 0.0245*
#     friendly and Audience: 0.12, p-value: 0.239
#     trustworthy and Audience: 0.0241, p-value: 0.813
# Scale: neg_eva
#     competent and neg_eva: -0.0186, p-value: 0.855
#     critical and neg_eva: 0.194, p-value: 0.0547
#     friendly and neg_eva: -0.0114, p-value: 0.911
#     trustworthy and neg_eva: -0.174, p-value: 0.0854
# Scale: liebowitz_fear
#     competent and liebowitz_fear: 0.0891, p-value: 0.381
#     critical and liebowitz_fear: 0.239, p-value: 0.0173*
#     friendly and liebowitz_fear: 0.0872, p-value: 0.391
#     trustworthy and liebowitz_fear: 0.0204, p-value: 0.841
# Scale: liebowitz_avoidance
#     competent and liebowitz_avoidance: 0.0508, p-value: 0.618
#     critical and liebowitz_avoidance: 0.215, p-value: 0.0323*
#     friendly and liebowitz_avoidance: 0.0306, p-value: 0.764
#     trustworthy and liebowitz_avoidance: -0.0482, p-value: 0.636

# %% [markdown]
# ### TODO
# - [ ] After inspecting the result, we found a significant correlation between critical judgment and SIAS. Now, we can draw scatter plots to visualize the relationship between social anxiety questionnaires and critical judgment. Try to write a loop to draw scatter plots for all social anxiety questionnaires. You can refer to the code above for drawing scatter plots.

# %% [markdown]
# # Save data

# %%
import time
# get the current date
date = time.strftime("%m-%d", time.localtime())
date

# create a directory to save the data
savepath = os.path.join(rootpath, 'result')
if not os.path.exists(savepath):
    os.makedirs(savepath)

# guilt
df_wide.to_csv(savepath+'/guilt_task_wide_'+date+'.csv', index=False)

# trait
df_wide_trait.to_csv(savepath+'/trait_task_wide_'+date+'.csv', index=False)

# questionnaires
df_qscores.to_csv(savepath+'/questionnaires_'+date+'.csv', index=False)

# pre_survey
pre_survey_clean.to_csv(savepath+'/pre_survey_'+date+'.csv', index=False)
